# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#Import data

death_rate_data = pd.read_csv('death_data.csv')

# %%
# Preview Data

death_rate_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Years                                23 non-null     int64
#  1   Accidents                            23 non-null     float64
#  2   Alzheimer's disease                  23 non-null     float64
#  3   Cancer                               23 non-null     float64
#  4   Chronic liver disease and cirrhosis  23 non-null     float64
#  5   Chronic lower respiratory diseases   23 non-null     float64
#  6   COVID-19                             2 non-null      float64
#  7   Diabetes                             23 non-null     float64
#  8   Heart disease                        23 non-null     float64
#  9   Homicide                             23 non-null     float64
#  10  Hypertension                         23 non-null     float64
# ...

# %%
death_rate_data.describe()
# Out:
#             Years  Accidents  Alzheimer's disease      Cancer  \
# count    23.00000  23.000000            23.000000   23.000000
# mean   2010.00000  42.226087            25.121739  171.760870
# std       6.78233   7.409037             4.372846   18.189351
# min    1999.00000  34.900000            16.500000  144.100000
# 25%    2004.50000  37.800000            23.050000  157.150000
# 50%    2010.00000  39.400000            24.200000  172.800000
# 75%    2015.50000  45.300000            29.600000  185.950000
# max    2021.00000  64.700000            32.400000  200.800000
#
#        Chronic liver disease and cirrhosis  \
# count                            23.000000
# mean                             10.156522
# std                               1.406099
# min                               8.800000
# 25%                               9.250000
# 50%                               9.600000
# 75%                              10.750000
# max                              14.500000
#
# ...

# %%
#preview
death_rate_data.head(10)
# Out:
#    Years  Accidents  Alzheimer's disease  Cancer  \
# 0   2021       64.7                 31.0   146.6
# 1   2020       57.6                 32.4   144.1
# 2   2019       49.3                 29.8   146.2
# 3   2018       48.0                 30.5   149.1
# 4   2017       49.4                 31.0   152.5
# 5   2016       47.4                 30.3   155.8
# 6   2015       43.2                 29.4   158.5
# 7   2014       40.5                 25.4   161.2
# 8   2013       39.4                 23.5   163.2
# 9   2012       39.1                 23.8   166.5
#
#    Chronic liver disease and cirrhosis  Chronic lower respiratory diseases  \
# 0                                 14.5                                34.7
# 1                                 13.3                                36.4
# 2                                 11.3                                38.2
# 3                                 11.1                                39.7
# ...

# %%
# Check for missing values
print(death_rate_data.isnull().sum())
# Out:
# Years                                   0
# Accidents                               0
# Alzheimer's disease                     0
# Cancer                                  0
# Chronic liver disease and cirrhosis     0
# Chronic lower respiratory diseases      0
# COVID-19                               21
# Diabetes                                0
# Heart disease                           0
# Homicide                                0
# Hypertension                            0
# Influenza and pneumonia                 0
# Nephritis                               0
# Parkinson's disease                     0
# Septicemia                              0
# Stroke                                  0
# Suicide                                 0
# dtype: int64

# %%
death_rate_data = death_rate_data.fillna(0)
print(death_rate_data.isnull().sum())
# Out:
# Years                                  0
# Accidents                              0
# Alzheimer's disease                    0
# Cancer                                 0
# Chronic liver disease and cirrhosis    0
# Chronic lower respiratory diseases     0
# COVID-19                               0
# Diabetes                               0
# Heart disease                          0
# Homicide                               0
# Hypertension                           0
# Influenza and pneumonia                0
# Nephritis                              0
# Parkinson's disease                    0
# Septicemia                             0
# Stroke                                 0
# Suicide                                0
# dtype: int64

# %% [markdown]
# ###### Plot each year separately

# %%
# Drop causes: Suicide, Accidents, Homicide
death_rate_data = death_rate_data.drop(columns=['Suicide'])
death_rate_data = death_rate_data.drop(columns=['Accidents'])
death_rate_data = death_rate_data.drop(columns=['Homicide'])

# %%
# Plot all causes of death in one graph







plt.figure(figsize=(14, 8))

    plt.plot(death_rate_data['Years'], death_rate_data[cause], marker='o', linestyle='-', label=cause)

plt.title('Trends in Death Rates by Cause (2017-2021)')
plt.xlabel('Year')
plt.ylabel('Death Rate (per 100,000 people)')
plt.legend()
plt.grid(True)
plt.show()

# Calculate the yearly percentage change from the previous year
death_rate_data_pct_change = death_rate_data.set_index('Years').pct_change().dropna() * 100

# Plot the percentage changes for each cause of death in one graph
plt.figure(figsize=(14, 8))
#for cause in death_rate_data.columns[1:]:
    plt.plot(death_rate_data_pct_change.index, death_rate_data_pct_change[cause], marker='o', linestyle='-', label=cause)

plt.title('Yearly Percentage Changes in Death Rates by Cause (2017-2021)')
plt.xlabel('Year')
plt.ylabel('Percentage Change in Death Rate')
plt.legend()
plt.grid(True)
plt.show()
